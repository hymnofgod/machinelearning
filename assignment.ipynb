# %% [markdown]
# <a href="https://colab.research.google.com/github/hymnofgod/machinelearning/blob/main/assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/College/world_population.csv")
df.head(5)
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df=pd.read_table("/content/drive/MyDrive/Colab Notebooks/College/countries of the world.txt")

df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df=pd.read_json("/content/drive/MyDrive/Colab Notebooks/College/json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/College/world_population_excel_workbook.xlsx",sheet_name="Sheet1")
df
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/College/world_population.csv",header=None)
df
# Out:
#        0     1                  2          3          4                5   \
# 0    Rank  CCA3            Country    Capital  Continent  2022 Population
# 1      36   AFG        Afghanistan      Kabul       Asia         41128771
# 2     138   ALB            Albania     Tirana     Europe          2842321
# 3      34   DZA            Algeria    Algiers     Africa         44903225
# 4     213   ASM     American Samoa  Pago Pago    Oceania            44273
# ..    ...   ...                ...        ...        ...              ...
# 230   226   WLF  Wallis and Futuna   Mata-Utu    Oceania            11572
# 231   172   ESH     Western Sahara   El Aaiún     Africa           575986
# 232    46   YEM              Yemen      Sanaa       Asia         33696614
# 233    63   ZMB             Zambia     Lusaka     Africa         20017675
# 234    74   ZWE           Zimbabwe     Harare     Africa         16320537
#
#                   6                7                8                9   \
# ...

# %%
#fileter the rank

#Display the list of countries having a rank<= 10

df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/College/world_population.csv")
x=df[df["Rank"]<=10]
x
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# ...

# %%
#Create a list of specific country ['Bangladesh', 'Brazil'] and return df which falls under the specific list only

country=df[df["Country"].isin(['Bangladesh', 'Brazil'])]
country_list=list(country)
country_list
# Out:
# ['Rank',
#  'CCA3',
#  'Country',
#  'Capital',
#  'Continent',
#  '2022 Population',
#  '2020 Population',
#  '2015 Population',
#  '2010 Population',
#  '2000 Population',
#  '1990 Population',
#  '1980 Population',
#  '1970 Population',
#  'Area (km²)',
#  'Density (per km²)',
#  'Growth Rate',
#  'World Population Percentage']

# %%
# Apply filter to the Country which has United in its name

country_filter=df[df.Country.str.contains('United')]
country_filter
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
# Create a dataframe df2 and give Country as its index
df2=df
df2=df2.set_index('Country')
df2
# df2 = (index=Country.index)
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
#Apply filter Continent and CCA3 in df2 (need only two columns)

df[['Continent','CCA3']]
# Out:
#     Continent CCA3
# 0        Asia  AFG
# 1      Europe  ALB
# 2      Africa  DZA
# 3     Oceania  ASM
# 4      Europe  AND
# ..        ...  ...
# 229   Oceania  WLF
# 230    Africa  ESH
# 231      Asia  YEM
# 232    Africa  ZMB
# 233    Africa  ZWE
#
# [234 rows x 2 columns]

# %%
#Apply filter to see details of Zimbabwe entire row
df[df['Country']=='Zimbabwe']
# Out:
#      Rank CCA3   Country Capital Continent  2022 Population  2020 Population  \
# 233    74  ZWE  Zimbabwe  Harare    Africa       16320537.0       15669666.0
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 233       14154937.0       12839771.0       11834676.0       10113893.0
#
#      1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 233        7049926.0        5202918.0    390757.0            41.7665
#
#      Growth Rate  World Population Percentage
# 233       1.0204                          0.2

# %%
df["Continent"]
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 229    Oceania
# 230     Africa
# 231       Asia
# 232     Africa
# 233     Africa
# Name: Continent, Length: 234, dtype: object

# %%
df[df["Rank"] < 10][["Rank", "Country", "Continent"]]
# Out:
#      Rank        Country      Continent
# 16      8     Bangladesh           Asia
# 27      7         Brazil  South America
# 41      1          China           Asia
# 92      2          India           Asia
# 93      4      Indonesia           Asia
# 149     6        Nigeria         Africa
# 156     5       Pakistan           Asia
# 171     9         Russia         Europe
# 221     3  United States  North America

# %%
#continent in descending order

#for sorting

# df.sort_values("Continent", ascending=False)

#for showing
# df[["Rank", "Country", "Continent"]]

#now combine with a .
df[df["Rank"] < 10].sort_values("Continent", ascending=False)[["Rank", "Country", "Continent"]]
# Out:
#      Rank        Country      Continent
# 27      7         Brazil  South America
# 221     3  United States  North America
# 171     9         Russia         Europe
# 16      8     Bangladesh           Asia
# 41      1          China           Asia
# 92      2          India           Asia
# 93      4      Indonesia           Asia
# 156     5       Pakistan           Asia
# 149     6        Nigeria         Africa

# %%
#continent in ascending order

#for sorting

# df.sort_values("Continent", ascending=False)

#for showing
# df[["Rank", "Country", "Continent"]]

#now combine with a .
df[df["Rank"] < 10].sort_values("Continent", ascending=True)[["Rank", "Country", "Continent"]]
# Out:
#      Rank        Country      Continent
# 149     6        Nigeria         Africa
# 16      8     Bangladesh           Asia
# 41      1          China           Asia
# 92      2          India           Asia
# 93      4      Indonesia           Asia
# 156     5       Pakistan           Asia
# 171     9         Russia         Europe
# 221     3  United States  North America
# 27      7         Brazil  South America
